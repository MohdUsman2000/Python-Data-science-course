# %% [markdown]
# String and Text
# - A string is a sequence of chracters
# - a string is a sequence of unicode characters.
# - string can be created by enclosing charcater inside a single quote, double quotes, triple quotes(used to represent multiline string and docstrings)

# %%
my_string ="hello"
print(my_string)

my_string='hello'
print(my_string)

my_string= '''hello'''
print(my_string)

my_string="""hello, welcome"""
print(my_string)
# Out:
# hello
# hello
# hello
# hello, welcome
