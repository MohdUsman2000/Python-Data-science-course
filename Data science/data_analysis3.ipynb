# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
filepath = 'cps_85_wages.csv'
if not os.path.exists(filepath):
    print('File not found')
else:
    df = pd.read_csv(filepath, index_col=0)
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534 entries, 8 to 16
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SOUTH       534 non-null    object
#  1   SEX         534 non-null    object
#  2   EXPERIENCE  534 non-null    int64
#  3   UNION       534 non-null    object
#  4   WAGE        534 non-null    float64
#  5   AGE         534 non-null    int64
#  6   RACE        534 non-null    object
#  7   OCCUPATION  534 non-null    object
#  8   SECTOR      534 non-null    object
#  9   MARR        534 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 45.9+ KB
# None

# %%
df.describe()
# Out:
#        EXPERIENCE        WAGE         AGE
# count  534.000000  534.000000  534.000000
# mean    17.822097    9.024064   36.833333
# std     12.379710    5.139097   11.726573
# min      0.000000    1.000000   18.000000
# 25%      8.000000    5.250000   28.000000
# 50%     15.000000    7.780000   35.000000
# 75%     26.000000   11.250000   44.000000
# max     55.000000   44.500000   64.000000

# %%
df.head()
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION  WAGE  AGE      RACE  \
# EDUCATION
# 8            no  female          21  not_member  5.10   35  Hispanic
# 9            no  female          42  not_member  4.95   57     White
# 12           no    male           1  not_member  6.67   19     White
# 12           no    male           4  not_member  4.00   22     White
# 12           no    male          17  not_member  7.50   35     White
#
#           OCCUPATION         SECTOR       MARR
# EDUCATION
# 8              Other  Manufacturing    Married
# 9              Other  Manufacturing    Married
# 12             Other  Manufacturing  Unmarried
# 12             Other          Other  Unmarried
# 12             Other          Other    Married

# %%
df.plot(kind = 'scatter' , x = 'AGE', y = 'EXPERIENCE',alpha=.5, 
c = 'EXPERIENCE' , cmap = 'viridis', figsize =(10,7), marker = 's', s= 'AGE',
edgecolor = 'black')
# Out:
# <AxesSubplot: xlabel='AGE', ylabel='EXPERIENCE'>

# %%
df.plot(kind = 'scatter' , x = 'AGE', y = 'WAGE',alpha=.5, 
c = 'EXPERIENCE' , cmap = 'viridis', figsize =(10,7), marker = 's', s= 'AGE',
edgecolor = 'black')
# Out:
# <AxesSubplot: xlabel='AGE', ylabel='WAGE'>

# %%
df
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE      RACE  \
# EDUCATION
# 8            no  female          21  not_member   5.10   35  Hispanic
# 9            no  female          42  not_member   4.95   57     White
# 12           no    male           1  not_member   6.67   19     White
# 12           no    male           4  not_member   4.00   22     White
# 12           no    male          17  not_member   7.50   35     White
# ...         ...     ...         ...         ...    ...  ...       ...
# 18           no    male           5  not_member  11.36   29     White
# 12           no  female          33  not_member   6.10   51     Other
# 17           no  female          25      member  23.25   48     Other
# 12          yes    male          13      member  19.88   31     White
# 16           no    male          33  not_member  15.38   55     White
#
#              OCCUPATION         SECTOR       MARR
# EDUCATION
# 8                 Other  Manufacturing    Married
# 9                 Other  Manufacturing    Married
# 12                Other  Manufacturing  Unmarried
# 12                Other          Other  Unmarried
# 12                Other          Other    Married
# ...                 ...            ...        ...
# 18         Professional          Other  Unmarried
# 12         Professional          Other    Married
# 17         Professional          Other    Married
# 12         Professional          Other    Married
# 16         Professional  Manufacturing    Married
#
# [534 rows x 10 columns]

# %%
df[['SOUTH', 'AGE']] #SUBSET
# Out:
#           SOUTH  AGE
# EDUCATION
# 8            no   35
# 9            no   57
# 12           no   19
# 12           no   22
# 12           no   35
# ...         ...  ...
# 18           no   29
# 12           no   51
# 17           no   48
# 12          yes   31
# 16           no   55
#
# [534 rows x 2 columns]

# %% [markdown]
# PIVOT TABLE

# %%
df.pivot_table(values='AGE', index='SECTOR',aggfunc=['mean','max','min','median'])
# Out:
#                     mean max min median
#                      AGE AGE AGE    AGE
# SECTOR
# Construction   40.083333  61  20   42.5
# Manufacturing  37.838384  64  19   35.0
# Other          36.401460  64  18   35.0

# %%
df.pivot_table(values='AGE',index='SECTOR', columns='SEX').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='SECTOR'>

# %%
df.pivot_table(values='WAGE',index='SECTOR', columns='SEX').plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='SECTOR'>

# %%
df['SECTOR']=='Manufacturing' #this is boolean filter
# Out:
# EDUCATION
# 8      True
# 9      True
# 12     True
# 12    False
# 12    False
#       ...
# 18    False
# 12    False
# 17    False
# 12    False
# 16     True
# Name: SECTOR, Length: 534, dtype: bool

# %%
df[df['SECTOR']=='Manufacturing'] #boolean filtering
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE      RACE  \
# EDUCATION
# 8            no  female          21  not_member   5.10   35  Hispanic
# 9            no  female          42  not_member   4.95   57     White
# 12           no    male           1  not_member   6.67   19     White
# 16           no    male          11  not_member  13.28   33     White
# 12           no    male          19      member  11.50   37     White
# ...         ...     ...         ...         ...    ...  ...       ...
# 17           no    male           3  not_member  20.40   26     White
# 14           no    male          19  not_member  16.42   39     White
# 18           no  female          37  not_member  22.83   61     White
# 16           no    male          17  not_member  22.50   39     White
# 16           no    male          33  not_member  15.38   55     White
#
#              OCCUPATION         SECTOR       MARR
# EDUCATION
# 8                 Other  Manufacturing    Married
# 9                 Other  Manufacturing    Married
# 12                Other  Manufacturing  Unmarried
# 16                Other  Manufacturing    Married
# 12                Other  Manufacturing  Unmarried
# ...                 ...            ...        ...
# 17         Professional  Manufacturing  Unmarried
# 14         Professional  Manufacturing  Unmarried
# 18         Professional  Manufacturing  Unmarried
# 16         Professional  Manufacturing    Married
# 16         Professional  Manufacturing    Married
#
# [99 rows x 10 columns]

# %%
df[~(df['SECTOR']=='Manufacturing')]
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE   RACE  \
# EDUCATION
# 12           no    male           4  not_member   4.00   22  White
# 12           no    male          17  not_member   7.50   35  White
# 13           no    male           9      member  13.07   28  White
# 10          yes    male          27  not_member   4.45   43  White
# 12           no    male           9  not_member  19.47   27  White
# ...         ...     ...         ...         ...    ...  ...    ...
# 16           no  female           6      member  11.79   28  White
# 18           no    male           5  not_member  11.36   29  White
# 12           no  female          33  not_member   6.10   51  Other
# 17           no  female          25      member  23.25   48  Other
# 12          yes    male          13      member  19.88   31  White
#
#              OCCUPATION SECTOR       MARR
# EDUCATION
# 12                Other  Other  Unmarried
# 12                Other  Other    Married
# 13                Other  Other  Unmarried
# 10                Other  Other  Unmarried
# 12                Other  Other  Unmarried
# ...                 ...    ...        ...
# 16         Professional  Other  Unmarried
# 18         Professional  Other  Unmarried
# 12         Professional  Other    Married
# 17         Professional  Other    Married
# 12         Professional  Other    Married
#
# [435 rows x 10 columns]

# %%
explt10=df['EXPERIENCE']<= 10 #boolean filter
df[explt10]
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE   RACE  \
# EDUCATION
# 12           no    male           1  not_member   6.67   19  White
# 12           no    male           4  not_member   4.00   22  White
# 13           no    male           9      member  13.07   28  White
# 12           no    male           9  not_member  19.47   27  White
# 12           no    male           9  not_member   8.75   27  White
# ...         ...     ...         ...         ...    ...  ...    ...
# 16           no    male          10      member   7.50   32  White
# 17          yes    male           2  not_member   7.00   25  White
# 15           no    male          10  not_member  12.50   31  White
# 16           no  female           6      member  11.79   28  White
# 18           no    male           5  not_member  11.36   29  White
#
#              OCCUPATION         SECTOR       MARR
# EDUCATION
# 12                Other  Manufacturing  Unmarried
# 12                Other          Other  Unmarried
# 13                Other          Other  Unmarried
# 12                Other          Other  Unmarried
# 12                Other          Other  Unmarried
# ...                 ...            ...        ...
# 16         Professional          Other    Married
# 17         Professional          Other    Married
# 15         Professional          Other  Unmarried
# 16         Professional          Other  Unmarried
# 18         Professional          Other  Unmarried
#
# [179 rows x 10 columns]

# %%
df[explt10].plot(kind='box', x='EXPERIENCE' , y ='WAGE')
# Out:
# <AxesSubplot: >

# %% [markdown]
# sorting

# %%
df
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE      RACE  \
# EDUCATION
# 8            no  female          21  not_member   5.10   35  Hispanic
# 9            no  female          42  not_member   4.95   57     White
# 12           no    male           1  not_member   6.67   19     White
# 12           no    male           4  not_member   4.00   22     White
# 12           no    male          17  not_member   7.50   35     White
# ...         ...     ...         ...         ...    ...  ...       ...
# 18           no    male           5  not_member  11.36   29     White
# 12           no  female          33  not_member   6.10   51     Other
# 17           no  female          25      member  23.25   48     Other
# 12          yes    male          13      member  19.88   31     White
# 16           no    male          33  not_member  15.38   55     White
#
#              OCCUPATION         SECTOR       MARR
# EDUCATION
# 8                 Other  Manufacturing    Married
# 9                 Other  Manufacturing    Married
# 12                Other  Manufacturing  Unmarried
# 12                Other          Other  Unmarried
# 12                Other          Other    Married
# ...                 ...            ...        ...
# 18         Professional          Other  Unmarried
# 12         Professional          Other    Married
# 17         Professional          Other    Married
# 12         Professional          Other    Married
# 16         Professional  Manufacturing    Married
#
# [534 rows x 10 columns]

# %%
df.sort_values(by='AGE', inplace=True)

# %%
df
# Out:
#           SOUTH     SEX  EXPERIENCE       UNION   WAGE  AGE      RACE  \
# EDUCATION
# 16           no  female           0  not_member  10.00   18     White
# 12           no  female           0  not_member   3.35   18     White
# 12           no  female           0  not_member   5.00   18     White
# 12           no    male           0  not_member   3.35   18     White
# 13           no    male           0  not_member   4.00   19     White
# ...         ...     ...         ...         ...    ...  ...       ...
# 14          yes    male          44  not_member  19.98   64     White
# 12          yes  female          46  not_member   4.00   64     White
# 3           yes    male          55  not_member   7.00   64  Hispanic
# 16           no  female          42  not_member  11.71   64     White
# 18           no  female          40  not_member  22.20   64     White
#
#              OCCUPATION         SECTOR       MARR
# EDUCATION
# 16         Professional          Other  Unmarried
# 12              Service          Other  Unmarried
# 12             Clerical          Other  Unmarried
# 12                Other          Other  Unmarried
# 13                Other          Other  Unmarried
# ...                 ...            ...        ...
# 14                Sales          Other    Married
# 12                Other          Other  Unmarried
# 3                 Other  Manufacturing    Married
# 16             Clerical  Manufacturing  Unmarried
# 18         Professional          Other  Unmarried
#
# [534 rows x 10 columns]

# %%
df.sort_values(by=['RACE','WAGE'], ascending=[False, True], inplace=True)

# %% [markdown]
# GROUPBY

# %%
df.groupby('OCCUPATION')['EXPERIENCE'].mean()
# Out:
# OCCUPATION
# Clerical        17.577320
# Management      18.072727
# Other           18.064103
# Professional    15.457143
# Sales           18.447368
# Service         20.192771
# Name: EXPERIENCE, dtype: float64

# %%
df.groupby('OCCUPATION')['EXPERIENCE'].agg(['mean','min','max','median','std'])
# Out:
#                    mean  min  max  median        std
# OCCUPATION
# Clerical      17.577320    0   45    15.0  12.124214
# Management    18.072727    1   42    15.0  11.375501
# Other         18.064103    0   55    15.0  12.448438
# Professional  15.457143    0   42    13.0  10.275090
# Sales         18.447368    0   45    15.5  13.492135
# Service       20.192771    0   54    17.0  14.718876

# %%
df.groupby('OCCUPATION')['EXPERIENCE','WAGE'].mean().plot(kind='bar')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_256\255127886.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('OCCUPATION')['EXPERIENCE','WAGE'].mean().plot(kind='bar')
# <AxesSubplot: xlabel='OCCUPATION'>

# %%
df.groupby('OCCUPATION')['EXPERIENCE','WAGE'].mean().plot(kind='box')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_256\2347050217.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('OCCUPATION')['EXPERIENCE','WAGE'].mean().plot(kind='box')
# <AxesSubplot: >
